# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("awaiskaggler/insurance-csv")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 13.4k/13.4k [00:00<00:00, 6.54MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/awaiskaggler/insurance-csv/versions/1

# %%
import pandas as pd

# Path to the dataset
dataset_path = "/root/.cache/kagglehub/datasets/awaiskaggler/insurance-csv/versions/1/insurance.csv"

# Load the dataset
data = pd.read_csv(dataset_path)

# Display the first few rows
print(data.head())
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
ages = data['age']
expenses = data['expenses']

# Factors (categorical data)
smoking_status = pd.Categorical(data['smoker'])

# Lists
age_list = list(data['age'])

# Matrices
matrix = data[['age', 'bmi', 'expenses']].to_numpy()

# Data frame
df_subset = data[['age', 'smoker', 'sex', 'expenses']]

# b) Generate a scatter plot with customization
plt.figure(figsize=(8, 6))
plt.scatter(data['age'], data['expenses'], c='blue', alpha=0.7, marker='+')
plt.title('Scatter Plot of Age vs Expenses', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Expenses', fontsize=12)
plt.grid(True)
plt.annotate('Example Point', xy=(data['age'].iloc[0], data['expenses'].iloc[0]),
             xytext=(10, 20), textcoords='offset points',
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.show()

# %%
# c) Filter data and update the plot
filtered_data = data[(data['age'] >= 20) & (data['age'] <= 40)]
plt.figure(figsize=(8, 6))
plt.scatter(filtered_data['age'], filtered_data['expenses'], c='green', alpha=0.7, marker='o')
plt.title('Scatter Plot of Age (20-40) vs Expenses', fontsize=14)
plt.xlabel('Age (20-40)', fontsize=12)
plt.ylabel('Expenses', fontsize=12)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x='age', y='smoker', hue='smoker', palette='Set1', s=100)
plt.title('Scatter Plot of Age vs Smoking', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Smoking Status', fontsize=12)
plt.grid(True)
plt.show()

# %%
# Plot expenses of smokers and non-smokers
grouped_expenses = data.groupby('smoker')['expenses'].mean()
grouped_expenses.plot(kind='bar', color=['red', 'blue'], title='Average Expenses of Smokers vs Non-Smokers')
plt.ylabel('Average Expenses')
plt.show()

# %%
smoker_gender_count = data[data['smoker'] == 'yes'].groupby('sex').size()
smoker_gender_count.plot(kind='bar', color=['orange', 'purple'], title='Number of Smokers by Gender')
plt.ylabel('Count')
plt.show()

# %%
# Scatter plot: Age vs Expenses
plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x='age', y='expenses', hue='smoker', palette='coolwarm', s=100)
plt.title('Scatter Plot of Age vs Expenses', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Expenses', fontsize=12)
plt.grid(True)
plt.show()
